# %%
# Import necessary libraries and modules
import os
import glob
import pickle
import numpy
from music21 import *
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation, BatchNormalization
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from google.colab import drive

# Define the MusicGenerator class
class MusicGenerator:
    def __init__(self, genre_id, weight_name="weights.hdf5"):
        # Initialize the MusicGenerator with a specific genre and weight name
        self.genre_id = genre_id
        self.weight_name = weight_name

        # Define genre folders for different genres
        self.genre_folders = {
            1: "/content/drive/MyDrive/project/classic",
            2: "/content/drive/MyDrive/project/movie",
            3: "/content/drive/MyDrive/project/pop",
            4: "/content/drive/MyDrive/project/rock"
        }
        # Set the genre folder based on the provided genre_id
        self.genre_folder = self.genre_folders.get(genre_id)
        if self.genre_folder is None:
            raise ValueError("Invalid genre ID. Choose a valid genre.")

        # Mount Google Drive to access files
        drive.mount('/content/drive')
        self.drive_path = self.genre_folder

    # Function to extract data from MIDI files
    def get_data(self):
        data = []
        for file in glob.glob(os.path.join(self.drive_path, "*.mid")):
            aud = converter.parse(file)
            print('Midifiles:', file)
            datatp = None
            try:
                instru = instrument.partitionByInstrument(aud)
                datatp = instru.parts[0].recurse()
            except:
                datatp = aud.flat.data
            for element in datatp:
                if isinstance(element, note.Note):
                    data.append(str(element.pitch))
                elif isinstance(element, chord.Chord):
                    data.append('.'.join(str(n) for n in element.normalOrder))

        # Save the extracted data to a pickle file
        path = open(f'/content/drive/MyDrive/project/model/training_data', 'wb')
        pickle.dump(data, path)
        print(path, data)
        return data

    # Function to create sequences from the data
    def sequence(self, data, amount_of_pitch):
        squelength = 100
        pitch = sorted(set(item for item in data))
        daoin = dict((note, number) for number, note in enumerate(pitch))
        niput = []
        output = []
        for i in range(0, len(data) - squelength, 1):
            squein = data[i:i + squelength]
            squeout = data[i + squelength]
            niput.append([daoin[char] for char in squein])
            output.append([daoin[squeout]])
        ilength = len(niput)
        niput = numpy.reshape(niput, (ilength, squelength, 1))
        niput = niput / float(amount_of_pitch)
        output = to_categorical(output)
        return niput, output

    # Function to create the LSTM model
    def create_model(self, niput, amount_of_pitch):
        model = Sequential()
        model.add(LSTM(512, input_shape=(niput.shape[1], niput.shape[2]), recurrent_dropout=0.3, return_sequences=True))
        model.add(LSTM(512, recurrent_dropout=0.3, return_sequences=True,))
        model.add(LSTM(512))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(Dense(256))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(Dense(amount_of_pitch))
        model.add(Activation('softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
        return model

    # Function to train the LSTM model
    def train_network(self, model, niput, output):
        fp = f"/content/drive/MyDrive/project/weight/{self.weight_name}"
        checkpoint = ModelCheckpoint(
            fp,
            monitor='loss',
            verbose=0,
            save_best_only=True,
            mode='min'
        )
        callbacks_list = [checkpoint]
        model.fit(niput, output, epochs=10, batch_size=128, callbacks=callbacks_list)

    # Function to execute all steps
    def get_all_function(self):
        data = self.get_data()
        amount_of_pitch = len(set(data))
        niput, output = self.sequence(data, amount_of_pitch)
        model = self.create_model(niput, amount_of_pitch)
        self.train_network(model, niput, output)

# Main block
if __name__ == '__main__':
    # Get user input for genre ID
    genre_id = int(input("Enter the genre ID (1 for classic, 2 for movie, 3 for pop, 4 for rock): "))

    # Create an instance of MusicGenerator and execute all functions
    music_generator = MusicGenerator(genre_id)
    music_generator.get_all_function()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Midifiles: /content/drive/MyDrive/project/classic/alb_esp5.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_esp4.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_esp2.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se6.mid
# Midifiles: /content/drive/MyDrive/project/classic/bach_850.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se3.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se2.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se7.mid
# Midifiles: /content/drive/MyDrive/project/classic/bach_847.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_esp1.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se8.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se5.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_esp6.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se4.mid
# Midifiles: /content/drive/MyDrive/project/classic/islamei.mid
# Midifiles: /content/drive/MyDrive/project/classic/bach_846.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_se1.mid
# Midifiles: /content/drive/MyDrive/project/classic/alb_esp3.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_les_adieux_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus10_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps6.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps2.mid
# Midifiles: /content/drive/MyDrive/project/classic/appass_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus22_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/elise.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_hammerklavier_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/waldstein_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus22_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus90_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/appass_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mond_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps7.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus10_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps1.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus22_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/appass_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mond_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_hammerklavier_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus90_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_les_adieux_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/waldstein_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps5.mid
# Midifiles: /content/drive/MyDrive/project/classic/pathetique_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus10_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/waldstein_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps4.mid
# Midifiles: /content/drive/MyDrive/project/classic/bor_ps3.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_hammerklavier_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mond_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_hammerklavier_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_opus22_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/pathetique_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/pathetique_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/beethoven_les_adieux_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p18.mid
# Midifiles: /content/drive/MyDrive/project/classic/brahms_opus1_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p23.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_gewitter.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p2.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_perlen.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_quelle.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p21.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p24.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p15.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p22.mid
# Midifiles: /content/drive/MyDrive/project/classic/brahms_opus117_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p10.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p12.mid
# Midifiles: /content/drive/MyDrive/project/classic/brahms_opus117_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/brahms_opus1_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p14.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_erwachen.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_sylphen.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p17.mid
# Midifiles: /content/drive/MyDrive/project/classic/chp_op31.mid
# Midifiles: /content/drive/MyDrive/project/classic/brahms_opus1_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p1.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_trennung.mid
# Midifiles: /content/drive/MyDrive/project/classic/brahms_opus1_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/br_im5.mid
# Midifiles: /content/drive/MyDrive/project/classic/br_im2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p13.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_spinnerlied.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p20.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p19.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p16.mid
# Midifiles: /content/drive/MyDrive/project/classic/br_rhap.mid
# Midifiles: /content/drive/MyDrive/project/classic/chp_op18.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_geschwindigkeit.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p11.mid
# Midifiles: /content/drive/MyDrive/project/classic/burg_agitato.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p3.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op66.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p5.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op10_e05.mid
# Midifiles: /content/drive/MyDrive/project/classic/debussy_cc_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op27_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p8.mid
# Midifiles: /content/drive/MyDrive/project/classic/debussy_cc_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op7_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op35_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/deb_menu.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op23.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op10_e12.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op35_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op25_e3.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op33_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p6.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op25_e2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op25_e1.mid
# Midifiles: /content/drive/MyDrive/project/classic/debussy_cc_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p4.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op10_e01.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op33_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op53.mid
# Midifiles: /content/drive/MyDrive/project/classic/deb_prel.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op7_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op25_e4.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p9.mid
# Midifiles: /content/drive/MyDrive/project/classic/debussy_cc_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op27_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op25_e11.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op25_e12.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op35_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn-p7.mid
# Midifiles: /content/drive/MyDrive/project/classic/chpn_op35_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_7_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_halling.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_once_upon_a_time.mid
# Midifiles: /content/drive/MyDrive/project/classic/hay_40_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_33_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_wanderer.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_walzer.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_brooklet.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_43_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/hay_40_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_43_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_spring.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_wedding.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_7_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_7_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_8_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_33_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_zwerge.mid
# Midifiles: /content/drive/MyDrive/project/classic/gra_esp_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_43_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_march.mid
# Midifiles: /content/drive/MyDrive/project/classic/debussy_cc_6.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_album.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_elfentanz.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_butterfly.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_berceuse.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_35_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_voeglein.mid
# Midifiles: /content/drive/MyDrive/project/classic/gra_esp_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_33_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_35_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/gra_esp_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_kobold.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_35_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/grieg_waechter.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et_trans8.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op19_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et2.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_8_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_8_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op62_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et4.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_9_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_rhap09.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op19_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_donjuan.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_liebestraum.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et6.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_rhap02.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op62_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op30_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op19_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op19_6.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op19_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op62_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_9_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_8_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et5.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_rhap15.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op30_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/haydn_9_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_rhap12.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et_trans4.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et1.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op53_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_311_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op19_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op30_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op30_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_et_trans5.mid
# Midifiles: /content/drive/MyDrive/project/classic/mendel_op30_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_311_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/liz_rhap10.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_6.mid
# Midifiles: /content/drive/MyDrive/project/classic/schu_143_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D850_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d960_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_330_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_545_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_570_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_545_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_330_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_331_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_332_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d760_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_311_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d760_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_332_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_570_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d960_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_332_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_331_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_8.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_545_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_331_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_333_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_333_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d760_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d960_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_330_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_333_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_7.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d760_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/mz_570_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/schu_143_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/muss_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/schu_143_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/schub_d960_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_8.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/schumm-6.mid
# Midifiles: /content/drive/MyDrive/project/classic/schuim-1.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_9.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_7.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D850_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/schuim-4.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_12.mid
# Midifiles: /content/drive/MyDrive/project/classic/schuim-2.mid
# Midifiles: /content/drive/MyDrive/project/classic/schumm-1.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D850_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_13.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_6.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D935_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/schuim-3.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_5.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/schumm-5.mid
# Midifiles: /content/drive/MyDrive/project/classic/schumm-2.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D850_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/schumm-4.mid
# Midifiles: /content/drive/MyDrive/project/classic/schum_abegg.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_11.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D935_1.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_7.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn16_6.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D935_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_3.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_8.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_10.mid
# Midifiles: /content/drive/MyDrive/project/classic/schubert_D935_2.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn15_4.mid
# Midifiles: /content/drive/MyDrive/project/classic/schumm-3.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_februar.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_maerz.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_juni.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_august.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_september.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn68_10.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_dezember.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_november.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_januar.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_oktober.mid
# Midifiles: /content/drive/MyDrive/project/classic/scn68_12.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_mai.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_juli.mid
# Midifiles: /content/drive/MyDrive/project/classic/ty_april.mid
# Midifiles: /content/drive/MyDrive/project/classic/generated_music.mid
# <_io.BufferedWriter name='/content/drive/MyDrive/project/model/training_data'> ['C2', 'E3', 'G3', 'C4', 'E4', 'G5', 'E3', 'G3', 'C4', 'E4', 'G5', 'E3', 'G3', 'C4', 'E4', 'E3', 'G3', 'E5', 'C4', 'D5', 'F3', 'G3', 'B3', 'D4', 'G4', 'F3', 'G3', 'B3', 'C5', 'E3', 'G3', 'C4', 'E4', 'E5', 'E3', 'G3', 'C4', 'C3', 'C2', 'E3', 'G3', 'C4', 'E4', 'G5', 'E3', 'G3', 'C4', 'E4', 'G5', 'E3', 'G3', 'C4', 'E4', 'E3', 'G3', 'E5', 'C4', 'D5', 'F3', 'G3', 'B3', 'D4', 'G4', 'F3', 'G3', 'B3', 'C5', 'E3', 'G3', 'C4', 'E4', 'D4', 'C4', 'G2', 'B3', 'G1', 'G3', 'B3', 'D4', 'G4', 'F5', 'G3', 'B3', 'D4', 'G4', 'F5', 'G3', 'B3', 'D4', 'G4', 'G3', 'B3', 'D5', 'G4', 